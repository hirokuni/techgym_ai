# %%
#AI-TECHGYM-1-13-A-3
#自然言語処理

#word2vec データ読み込み
from gensim.models import KeyedVectors
import pandas as pd

# ダウンロード先のパスを指定
MODEL_FILENAME = "./stanby-jobs-200d-word2vector.bin"
w2v = KeyedVectors.load_word2vec_format(MODEL_FILENAME, binary=True)

# データの読み込み
df = pd.read_csv("words.csv") 

# 読み込んだデータのサンプルを取得
co_df = df

# 閾値を決める
THRESHOLD = 0.7

# 結果をlistで保存
result = []

# 類似度を計算
for i in df["words"].values:
    for j in co_df["words"].values:
        tmp = []
        # word2vecにない単語はスルーする
        try:
            similarity = w2v.similarity(i, j)
            # 類似度が0.99以上は同じ単語とする
            # 類似度がTHRESHOLD以上のものを抽出
            if similarity < 0.99 and similarity > THRESHOLD:
                tmp = [i,j,str(similarity)]
                result.append(tmp)
        except:
            pass

#リストを表示
print(result)

#データフレーム
df_result = pd.DataFrame(result,columns=["単語A","単語B","類似度"])
display(df_result)

#CSVファイルに保存
df_result.to_csv('./w2v_result.csv',index=False)
# Out:
# [['関東', '関西', '0.7552339'], ['北', '西', '0.81898963'], ['海', '山', '0.710297'], ['長崎', '福岡', '0.74066913'], ['福岡', '長崎', '0.74066913'], ['福岡', '東京', '0.7367493'], ['東京', '福岡', '0.7367493'], ['いろいろ', '色々', '0.7147816'], ['関西', '関東', '0.7552339'], ['関西', '九州', '0.71936744'], ['九州', '関西', '0.71936744'], ['山', '海', '0.710297'], ['西', '北', '0.81898963'], ['色々', 'いろいろ', '0.7147816']]
#      単語A   単語B         類似度
# 0     関東    関西   0.7552339
# 1      北     西  0.81898963
# 2      海     山    0.710297
# 3     長崎    福岡  0.74066913
# 4     福岡    長崎  0.74066913
# 5     福岡    東京   0.7367493
# 6     東京    福岡   0.7367493
# 7   いろいろ    色々   0.7147816
# 8     関西    関東   0.7552339
# 9     関西    九州  0.71936744
# 10    九州    関西  0.71936744
# 11     山     海    0.710297
# 12     西     北  0.81898963
# 13    色々  いろいろ   0.7147816
