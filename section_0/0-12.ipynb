# %%
import pandas as pd
import urllib

# %%
data = "http://archive.ics.uci.edu/ml/machine-learning-databases/balloons/adult+stretch.data"
urllib.request.urlretrieve(data, './adult+strech.dat')
# Out:
# ('./adult+strech.dat', <http.client.HTTPMessage at 0x11437b2b0>)

# %%
balloons = pd.read_csv('./adult+strech.dat')

# %%
display(balloons)
# Out:
#     YELLOW  SMALL  STRETCH  ADULT  T
# 0   YELLOW  SMALL  STRETCH  ADULT  T
# 1   YELLOW  SMALL  STRETCH  CHILD  F
# 2   YELLOW  SMALL      DIP  ADULT  F
# 3   YELLOW  SMALL      DIP  CHILD  F
# 4   YELLOW  LARGE  STRETCH  ADULT  T
# 5   YELLOW  LARGE  STRETCH  ADULT  T
# 6   YELLOW  LARGE  STRETCH  CHILD  F
# 7   YELLOW  LARGE      DIP  ADULT  F
# 8   YELLOW  LARGE      DIP  CHILD  F
# 9   PURPLE  SMALL  STRETCH  ADULT  T
# 10  PURPLE  SMALL  STRETCH  ADULT  T
# 11  PURPLE  SMALL  STRETCH  CHILD  F
# 12  PURPLE  SMALL      DIP  ADULT  F
# 13  PURPLE  SMALL      DIP  CHILD  F
# 14  PURPLE  LARGE  STRETCH  ADULT  T
# 15  PURPLE  LARGE  STRETCH  ADULT  T
# 16  PURPLE  LARGE  STRETCH  CHILD  F
# 17  PURPLE  LARGE      DIP  ADULT  F
# 18  PURPLE  LARGE      DIP  CHILD  F

# %%
txt = "http://archive.ics.uci.edu/ml/machine-learning-databases/balloons/balloons.names"
urllib.request.urlretrieve(txt, './balloons.names')
# Out:
# ('./balloons.names', <http.client.HTTPMessage at 0x115e4dac8>)

# %%
with open('balloons.names') as f:
    for line in f:
        print(line)

#with open(path) as f:
#    print(type(f))
# Out:
# 1. Title: Balloon databases
#
#
#
# 2. Source: Michael Pazzani (pazzani@ics.uci.edu)
#
#
#
# 3. Past usage
#
#    Pazzani, M. (1991). The influence of prior knowledge on concept acquisition:
#
#    Experimental and computational results. Journal of Experimental Psychology:
#
#    Learning, Memory & Cognition, 17, 3,  416-432.
#
#
#
# 4. Relevant information:
#
#    There are four data sets representing different conditions of an experiment.
#
#    All have the same attributes.
#
#    a. adult-stretch.data  Inflated is true if age=adult or act=stretch
#
#    b. adult+stretch.data  Inflated is true if age=adult and act=stretch
#
#    c. small-yellow.data   Inflated is true if (color=yellow and size = small) or
#
#    d. small-yellow+adult-stretch.data  Inflated is true if
#
#             (color=yellow and size = small) or (age=adult and act=stretch)
#
#
#
# 5. Number of attributes: 4
#
#
#
# 6. Number of Instances: 16
#
#
#
# 7. Attribute Information: (Classes Inflated T or F)
#
# ...

# %%
display(balloons.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
# YELLOW     19 non-null object
# SMALL      19 non-null object
# STRETCH    19 non-null object
# ADULT      19 non-null object
# T          19 non-null object
# dtypes: object(5)
# memory usage: 840.0+ bytes
# None

# %% [markdown]
# # 0-13

# %%
columns_name = ['color','size','act','age','inflated']
balloons.columns = columns_name
display(balloons)
display(pd.crosstab(balloons['color'], balloons['size']))
# Out:
#      color   size      act    age inflated
# 0   YELLOW  SMALL  STRETCH  ADULT        T
# 1   YELLOW  SMALL  STRETCH  CHILD        F
# 2   YELLOW  SMALL      DIP  ADULT        F
# 3   YELLOW  SMALL      DIP  CHILD        F
# 4   YELLOW  LARGE  STRETCH  ADULT        T
# 5   YELLOW  LARGE  STRETCH  ADULT        T
# 6   YELLOW  LARGE  STRETCH  CHILD        F
# 7   YELLOW  LARGE      DIP  ADULT        F
# 8   YELLOW  LARGE      DIP  CHILD        F
# 9   PURPLE  SMALL  STRETCH  ADULT        T
# 10  PURPLE  SMALL  STRETCH  ADULT        T
# 11  PURPLE  SMALL  STRETCH  CHILD        F
# 12  PURPLE  SMALL      DIP  ADULT        F
# 13  PURPLE  SMALL      DIP  CHILD        F
# 14  PURPLE  LARGE  STRETCH  ADULT        T
# 15  PURPLE  LARGE  STRETCH  ADULT        T
# 16  PURPLE  LARGE  STRETCH  CHILD        F
# 17  PURPLE  LARGE      DIP  ADULT        F
# 18  PURPLE  LARGE      DIP  CHILD        F
# size    LARGE  SMALL
# color
# PURPLE      5      5
# YELLOW      5      4

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(10, 10))
plt.subplot(2,2,1)
sns.countplot(x='color', data=balloons)
plt.subplot(2,2,2)
sns.countplot(x='color', hue='age', hue_order=['CHILD','ADULT'], data=balloons)
plt.subplot(2,2,3)
sns.countplot(x='color', hue='size', hue_order=['SMALL', 'LARGE'], data=balloons)

# %% [markdown]
# # 0-13 2nd

# %%
display(pd.crosstab(balloons['color'],balloons['size']))
# Out:
# size    LARGE  SMALL
# color
# PURPLE      5      5
# YELLOW      5      4

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2,2,1)
sns.countplot(x='color', data=balloons)
plt.subplot(2,2,2)
sns.countplot(x='color', hue='age', hue_order=['CHILD', 'ADULT'], data=balloons)
plt.subplot(2,2,3)
sns.countplot(x='color', hue='size', hue_order=['SMALL','LARGE'], data=balloons)
