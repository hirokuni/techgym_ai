# %%
import pandas as pd
import urllib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = "https://archive.ics.uci.edu/ml/machine-learning-databases/tic-tac-toe/tic-tac-toe.data"
TTT = pd.read_csv(data)
display(TTT)
# Out:
#      x x.1 x.2 x.3  o o.1 x.4 o.2 o.3  positive
# 0    x   x   x   x  o   o   o   x   o  positive
# 1    x   x   x   x  o   o   o   o   x  positive
# 2    x   x   x   x  o   o   o   b   b  positive
# 3    x   x   x   x  o   o   b   o   b  positive
# 4    x   x   x   x  o   o   b   b   o  positive
# 5    x   x   x   x  o   b   o   o   b  positive
# 6    x   x   x   x  o   b   o   b   o  positive
# 7    x   x   x   x  o   b   b   o   o  positive
# 8    x   x   x   x  b   o   o   o   b  positive
# 9    x   x   x   x  b   o   o   b   o  positive
# 10   x   x   x   x  b   o   b   o   o  positive
# 11   x   x   x   o  x   o   x   o   o  positive
# 12   x   x   x   o  x   o   o   x   o  positive
# 13   x   x   x   o  x   o   o   o   x  positive
# 14   x   x   x   o  x   o   o   b   b  positive
# 15   x   x   x   o  x   o   b   o   b  positive
# 16   x   x   x   o  x   o   b   b   o  positive
# 17   x   x   x   o  x   b   o   o   b  positive
# 18   x   x   x   o  x   b   o   b   o  positive
# ...

# %%
txt= "https://archive.ics.uci.edu/ml/machine-learning-databases/tic-tac-toe/tic-tac-toe.names"
urllib.request.urlretrieve(txt, './tic-tac-toe.names')
# Out:
# ('./tic-tac-toe.names', <http.client.HTTPMessage at 0x1a2a340c50>)

# %%
with open('./tic-tac-toe.names') as f:
    for inline in f:
        print(inline)
# Out:
# 1. Title: Tic-Tac-Toe Endgame database
#
#
#
# 2. Source Information
#
#    -- Creator: David W. Aha (aha@cs.jhu.edu)
#
#    -- Donor: David W. Aha (aha@cs.jhu.edu)
#
#    -- Date: 19 August 1991
#
#
#
# 3. Known Past Usage:
#
#    1. Matheus,~C.~J., \& Rendell,~L.~A. (1989).  Constructive
#
#       induction on decision trees.  In {\it Proceedings of the
#
#       Eleventh International Joint Conference on Artificial Intelligence}
#
#       (pp. 645--650).  Detroit, MI: Morgan Kaufmann.
#
#       -- CITRE was applied to 100-instance training and 200-instance test
#
#          sets.  In a study using various amounts of domain-specific
#
#          knowledge, its highest average accuracy was 76.7% (using the
#
#          final decision tree created for testing).
#
#
#
#    2. Matheus,~C.~J. (1990). Adding domain knowledge to SBL through
#
#       feature construction.  In {\it Proceedings of the Eighth National
#
#       Conference on Artificial Intelligence} (pp. 803--808).
#
# ...

# %%
display(TTT.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 10 columns):
# x           957 non-null object
# x.1         957 non-null object
# x.2         957 non-null object
# x.3         957 non-null object
# o           957 non-null object
# o.1         957 non-null object
# x.4         957 non-null object
# o.2         957 non-null object
# o.3         957 non-null object
# positive    957 non-null object
# dtypes: object(10)
# memory usage: 74.8+ KB
# None

# %%
#indexを説明からつける
columns_name = ['top-left','top-middle','top-right',
                'middle-left','middle-middle','middle-right',
                'bottom-left','bottom-middle','bottom-right','P-N']
TTT.columns = columns_name
display(TTT.info())
plt.figure(figsize=(10,10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 957 entries, 0 to 956
# Data columns (total 10 columns):
# top-left         957 non-null object
# top-middle       957 non-null object
# top-right        957 non-null object
# middle-left      957 non-null object
# middle-middle    957 non-null object
# middle-right     957 non-null object
# bottom-left      957 non-null object
# bottom-middle    957 non-null object
# bottom-right     957 non-null object
# P-N              957 non-null object
# dtypes: object(10)
# memory usage: 74.8+ KB
# None

# %%
sns.countplot('P-N', hue='middle-middle', hue_order=['x','o','b'], data=TTT)
